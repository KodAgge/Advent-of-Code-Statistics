# %%
from lib.pre_processing import DataLoader
from lib.plotting import Plotting

# %%
file_name = "data/2022_103987.json"
loader = DataLoader(file_name)
print(loader)

plotter = Plotting(loader)
plotter.plot_score_time_line(label="id")
# Out:
# Year: 2022 | Number of users: 200 | Board ID: 103987
# You provided neither a list of users nor to show the top n users. Choosing to show the top 5 users.

# %%
file_name = "data/2022_2278253.json"
loader = DataLoader(file_name)
print(loader)

plotter = Plotting(loader)
plotter.plot_score_time_line(label="id")
# Out:
# Year: 2022 | Number of users: 4 | Board ID: 2278253
# You provided neither a list of users nor to show the top n users. Choosing to show the top 5 users.

# %%
file_name = "data/2021_103987.json"
loader = DataLoader(file_name)
print(loader)

plotter = Plotting(loader)
plotter.plot_score_time_line(score_type="stars", n_top_users=200, label="id")
# Out:
# Year: 2021 | Number of users: 200 | Board ID: 103987
